# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloAmaya/NLP-OrganicDataSet/blob/Add-DataSets/Data_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
#print(json.loads(organicconsumers)

# %%
with open('raw_source_data/english/biased/fb.json','r') as json_file:
    data = json_file.read()
    fbdata = json.loads(data)
    print(len(fbdata))
    
    #print(fbdata[0])
    
    for a in range(10):
        for b in range(len(fbdata[a]['comments'])):
            print(fbdata[a]['comments'][b]['comment_text'])
            print()
# Out:
# 5035
# That was another administration.
#
# Why is the ex CEO of Monsanto appointed head of the FDA ?
#
# because he greased the palms of our "elected" leaders. and judges too
#
# the photo shown above is from a feed lot in California...it is labeled as such in the article...the claims are that the environmental impact of grass fed cows and feed lot cows are the same...which of course is not...just like you said- animals that graze on pastures continue the growth/life cycle of the forage if managed well
#
# THAT IS NOT GRASS FED MEET! NO GRASS THERE! YOU ARE FAKE NEWS!!! IF ANIMALS COULD RUN THE RANGE LIKE THEY USED TO, THE POOP FERTILIZES THE GRASS AND THE GRASS GROWS AND THE RAIN COMES AND WE ARE ALL HAPPY! LYING NWO HACKS!
#
# Big Ag has strong influential power due to money unfortunately...
#
# When you're getting flak from the establishment, you know you're over your target.
#
# Well written truthful article TY
#
# Anyone can be bought
#
# ...
